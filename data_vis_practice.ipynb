# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
data = pd.read_csv("nba_players_shooting.csv", index_col=0)

# %%
data.head()
# Out:
#           SHOOTER         X         Y   RANGE    DEFENDER SCORE
# INDEX
# 0      Seth Curry -3.808987  5.583621  (0, 4)  Chris Paul  MADE
# 1      Seth Curry -0.104279  5.919138  (0, 4)  Trae Young  MADE
# 2      Seth Curry -0.525864  8.912239  (0, 4)  Trae Young  MADE
# 3      Seth Curry -0.790616  7.503782  (0, 4)  Chris Paul  MADE
# 4      Seth Curry  2.119074  5.320534  (0, 4)  Trae Young  MADE

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 776 entries, 0 to 775
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SHOOTER   776 non-null    object
#  1   X         776 non-null    float64
#  2   Y         776 non-null    float64
#  3   RANGE     776 non-null    object
#  4   DEFENDER  776 non-null    object
#  5   SCORE     776 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 42.4+ KB

# %%
data[["RANGE", "SCORE"]]
# Out:
#           RANGE   SCORE
# INDEX
# 0        (0, 4)    MADE
# 1        (0, 4)    MADE
# 2        (0, 4)    MADE
# 3        (0, 4)    MADE
# 4        (0, 4)    MADE
# ...         ...     ...
# 771    (25, 29)  MISSED
# 772    (25, 29)  MISSED
# 773    (25, 29)  MISSED
# 774    (25, 29)  MISSED
# 775    (25, 29)  MISSED
#
# [776 rows x 2 columns]

# %%
data.SHOOTER.value_counts()
# Out:
# Trae Young           329
# Chris Paul           216
# Seth Curry           147
# Russell Westbrook     84
# Name: SHOOTER, dtype: int64

# %%
sns.set_style("darkgrid")

# %%
x = data.SHOOTER.value_counts().index
y1 = data.SHOOTER[data.SCORE == "MADE"].value_counts().values
y2 = data.SHOOTER[data.SCORE == "MISSED"].value_counts().values
plt.xlabel("shooter")
plt.bar(x, y1)
plt.bar(x, y2, bottom=y1)
plt.legend(["made", "missed"])

# %%
sns.countplot(x = "SHOOTER", data = data, )
plt.title("moomy")
plt.show()

# %%
sns.barplot(x = "SHOOTER", y = "X", data = data, errorbar=('ci', False) )
# Out:
# <AxesSubplot: xlabel='SHOOTER', ylabel='X'>

# %%
data.head()
# Out:
#           SHOOTER         X         Y   RANGE    DEFENDER SCORE
# INDEX
# 0      Seth Curry -3.808987  5.583621  (0, 4)  Chris Paul  MADE
# 1      Seth Curry -0.104279  5.919138  (0, 4)  Trae Young  MADE
# 2      Seth Curry -0.525864  8.912239  (0, 4)  Trae Young  MADE
# 3      Seth Curry -0.790616  7.503782  (0, 4)  Chris Paul  MADE
# 4      Seth Curry  2.119074  5.320534  (0, 4)  Trae Young  MADE

# %%
data.groupby(['SHOOTER', 'SCORE']).size().unstack().plot(kind='bar', stacked=True, color = ("red","yellow"), title = "lol", ylabel = "jh")
plt.show()

# %%
data.head()
# Out:
#           SHOOTER         X         Y   RANGE    DEFENDER SCORE
# INDEX
# 0      Seth Curry -3.808987  5.583621  (0, 4)  Chris Paul  MADE
# 1      Seth Curry -0.104279  5.919138  (0, 4)  Trae Young  MADE
# 2      Seth Curry -0.525864  8.912239  (0, 4)  Trae Young  MADE
# 3      Seth Curry -0.790616  7.503782  (0, 4)  Chris Paul  MADE
# 4      Seth Curry  2.119074  5.320534  (0, 4)  Trae Young  MADE

# %%
sns.scatterplot( x = "X", y = "Y", data =data, hue ="SHOOTER" )
plt.title("manger")
plt.show()

# %%
sns.lineplot(x="X", y="Y", data = data, hue = "SHOOTER")
# Out:
# <AxesSubplot: xlabel='X', ylabel='Y'>

# %%
data.head()
# Out:
#           SHOOTER         X         Y   RANGE    DEFENDER SCORE
# INDEX
# 0      Seth Curry -3.808987  5.583621  (0, 4)  Chris Paul  MADE
# 1      Seth Curry -0.104279  5.919138  (0, 4)  Trae Young  MADE
# 2      Seth Curry -0.525864  8.912239  (0, 4)  Trae Young  MADE
# 3      Seth Curry -0.790616  7.503782  (0, 4)  Chris Paul  MADE
# 4      Seth Curry  2.119074  5.320534  (0, 4)  Trae Young  MADE

# %%
sns.kdeplot(x = "X", data=data, fill = True, hue = "RANGE")
# Out:
# <AxesSubplot: xlabel='X', ylabel='Density'>

# %%
data.head()
# Out:
#           SHOOTER         X         Y   RANGE    DEFENDER SCORE
# INDEX
# 0      Seth Curry -3.808987  5.583621  (0, 4)  Chris Paul  MADE
# 1      Seth Curry -0.104279  5.919138  (0, 4)  Trae Young  MADE
# 2      Seth Curry -0.525864  8.912239  (0, 4)  Trae Young  MADE
# 3      Seth Curry -0.790616  7.503782  (0, 4)  Chris Paul  MADE
# 4      Seth Curry  2.119074  5.320534  (0, 4)  Trae Young  MADE

# %%
a = data.RANGE[data.SHOOTER == "Seth Curry"].value_counts()
a
# Out:
# (25, 29)    59
# (20, 24)    30
# (15, 19)    18
# (0, 4)      16
# (5, 9)      12
# (10, 14)    12
# Name: RANGE, dtype: int64

# %%
b =  data.RANGE[data.SHOOTER == "Seth Curry"].value_counts().values.sum()
b
# Out:
# 147

# %%
c = (a/b) * 100
c
# Out:
# (25, 29)    40.136054
# (20, 24)    20.408163
# (15, 19)    12.244898
# (0, 4)      10.884354
# (5, 9)       8.163265
# (10, 14)     8.163265
# Name: RANGE, dtype: float64

# %%
c.plot(kind = "bar")
# Out:
# <AxesSubplot: >

# %%
sns.barplot(x = c.index, y = c.values, color ="skyblue")
# Out:
# <AxesSubplot: >

# %%
data.head()
# Out:
#           SHOOTER         X         Y   RANGE    DEFENDER SCORE
# INDEX
# 0      Seth Curry -3.808987  5.583621  (0, 4)  Chris Paul  MADE
# 1      Seth Curry -0.104279  5.919138  (0, 4)  Trae Young  MADE
# 2      Seth Curry -0.525864  8.912239  (0, 4)  Trae Young  MADE
# 3      Seth Curry -0.790616  7.503782  (0, 4)  Chris Paul  MADE
# 4      Seth Curry  2.119074  5.320534  (0, 4)  Trae Young  MADE

# %%
a =data.SHOOTER.value_counts()

# %%
b= data.SHOOTER[data.SCORE == "MADE"].value_counts()

# %%
c = ((b/a)*100).round(2)
c
# Out:
# Trae Young           43.16
# Chris Paul           48.61
# Seth Curry           57.82
# Russell Westbrook    33.33
# Name: SHOOTER, dtype: float64

# %%
d = 100 - c
d
# Out:
# Trae Young           56.84
# Chris Paul           51.39
# Seth Curry           42.18
# Russell Westbrook    66.67
# Name: SHOOTER, dtype: float64

# %%
plt.bar(c.index, c.values, color='dodgerblue')
plt.bar(c.index, d.values, bottom=c.values, color='crimson')
plt.xlabel("players")
plt.ylabel("Shots")
plt.legend(["made", "missed"])
plt.title("% of Shots made and missed")
plt.show()

# %%
data.head()
# Out:
#           SHOOTER         X         Y   RANGE    DEFENDER SCORE
# INDEX
# 0      Seth Curry -3.808987  5.583621  (0, 4)  Chris Paul  MADE
# 1      Seth Curry -0.104279  5.919138  (0, 4)  Trae Young  MADE
# 2      Seth Curry -0.525864  8.912239  (0, 4)  Trae Young  MADE
# 3      Seth Curry -0.790616  7.503782  (0, 4)  Chris Paul  MADE
# 4      Seth Curry  2.119074  5.320534  (0, 4)  Trae Young  MADE

# %%
data.RANGE[data.SHOOTER =="Seth Curry"].value_counts()
# Out:
# (25, 29)    59
# (20, 24)    30
# (15, 19)    18
# (0, 4)      16
# (5, 9)      12
# (10, 14)    12
# Name: RANGE, dtype: int64

# %%
sns.countplot( x = data.SHOOTER[data.SCORE == "MADE"], hue = "RANGE", data = data,)
# Out:
# <AxesSubplot: xlabel='SHOOTER', ylabel='count'>

# %%
data.head()
# Out:
#           SHOOTER         X         Y   RANGE    DEFENDER SCORE
# INDEX
# 0      Seth Curry -3.808987  5.583621  (0, 4)  Chris Paul  MADE
# 1      Seth Curry -0.104279  5.919138  (0, 4)  Trae Young  MADE
# 2      Seth Curry -0.525864  8.912239  (0, 4)  Trae Young  MADE
# 3      Seth Curry -0.790616  7.503782  (0, 4)  Chris Paul  MADE
# 4      Seth Curry  2.119074  5.320534  (0, 4)  Trae Young  MADE

# %%
a
# Out:
# Trae Young           329
# Chris Paul           216
# Seth Curry           147
# Russell Westbrook     84
# Name: SHOOTER, dtype: int64

# %%
data.head()
# Out:
#           SHOOTER         X         Y   RANGE    DEFENDER SCORE
# INDEX
# 0      Seth Curry -3.808987  5.583621  (0, 4)  Chris Paul  MADE
# 1      Seth Curry -0.104279  5.919138  (0, 4)  Trae Young  MADE
# 2      Seth Curry -0.525864  8.912239  (0, 4)  Trae Young  MADE
# 3      Seth Curry -0.790616  7.503782  (0, 4)  Chris Paul  MADE
# 4      Seth Curry  2.119074  5.320534  (0, 4)  Trae Young  MADE

# %%
data.corr()
# Out:
# C:\Users\Reiketsu\AppData\Local\Temp\ipykernel_1080\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#           X         Y
# X  1.000000  0.046801
# Y  0.046801  1.000000

# %%
sns.heatmap(data.corr(),vmin = -1, cmap = ("RdBu"), center = 0, annot =True)
# Out:
# C:\Users\Reiketsu\AppData\Local\Temp\ipykernel_1080\1948724282.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),vmin = -1, cmap = ("RdBu"), center = 0, annot =True)
# <AxesSubplot: >

# %%
data.head()
# Out:
#           SHOOTER         X         Y   RANGE    DEFENDER SCORE
# INDEX
# 0      Seth Curry -3.808987  5.583621  (0, 4)  Chris Paul  MADE
# 1      Seth Curry -0.104279  5.919138  (0, 4)  Trae Young  MADE
# 2      Seth Curry -0.525864  8.912239  (0, 4)  Trae Young  MADE
# 3      Seth Curry -0.790616  7.503782  (0, 4)  Chris Paul  MADE
# 4      Seth Curry  2.119074  5.320534  (0, 4)  Trae Young  MADE

# %%
sns.displot(x = "X", data=data, kind = "kde", col = "SHOOTER", hue = "SCORE")

# %%
sns.catplot(x="RANGE", y = "Y", data = data, kind = "bar", ci = False, col = "SHOOTER")
# Out:
# C:\Users\Reiketsu\AppData\Local\Temp\ipykernel_1080\464770439.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.catplot(x="RANGE", y = "Y", data = data, kind = "bar", ci = False, col = "SHOOTER")
