# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
marvel_df= pd.DataFrame(marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
marvel_df.columns = "name","gender","first_appeareance"

# %%
marvel_df.index = marvel_df["name"]

# %%
marvel_df = marvel_df.drop(["name"], axis = "columns")

# %%
marvel_df
# Out:
#                   gender  first_appeareance
# name
# Spider-Man          male               1962
# Captain America     male               1941
# Wolverine           male               1974
# Iron Man            male               1963
# Thor                male               1963
# Thing               male               1961
# Mister Fantastic    male               1961
# Hulk                male               1962
# Beast               male               1963
# Invisible Woman   female               1961
# Storm             female               1975
# Namor               male               1939
# Hawkeye             male               1964
# Daredevil           male               1964
# Doctor Strange      male               1963
# Hank Pym            male               1962
# Scarlet Witch     female               1964
# Wasp              female               1963
# Black Widow       female               1964
# Vision              male               1968

# %%
marvel_df.drop("Namor")
# Out:
#                   gender  first_appeareance
# name
# Spider-Man          male               1962
# Captain America     male               1941
# Wolverine           male               1974
# Iron Man            male               1963
# Thor                male               1963
# Thing               male               1961
# Mister Fantastic    male               1961
# Hulk                male               1962
# Beast               male               1963
# Invisible Woman   female               1961
# Storm             female               1975
# Hawkeye             male               1964
# Daredevil           male               1964
# Doctor Strange      male               1963
# Hank Pym            male               1962
# Scarlet Witch     female               1964
# Wasp              female               1963
# Black Widow       female               1964
# Vision              male               1968

# %%
marvel_df.drop("Hank Pym")
# Out:
#                   gender  first_appeareance
# name
# Spider-Man          male               1962
# Captain America     male               1941
# Wolverine           male               1974
# Iron Man            male               1963
# Thor                male               1963
# Thing               male               1961
# Mister Fantastic    male               1961
# Hulk                male               1962
# Beast               male               1963
# Invisible Woman   female               1961
# Storm             female               1975
# Namor               male               1939
# Hawkeye             male               1964
# Daredevil           male               1964
# Doctor Strange      male               1963
# Scarlet Witch     female               1964
# Wasp              female               1963
# Black Widow       female               1964
# Vision              male               1968

# %%
marvel_df.head()
# Out:
#                 gender  first_appeareance
# name
# Spider-Man        male               1962
# Captain America   male               1941
# Wolverine         male               1974
# Iron Man          male               1963
# Thor              male               1963

# %%
marvel_df.iloc[:5]
# Out:
#                 gender  first_appeareance
# name
# Spider-Man        male               1962
# Captain America   male               1941
# Wolverine         male               1974
# Iron Man          male               1963
# Thor              male               1963

# %%
marvel_df.iloc[-5:]
# Out:
#                gender  first_appeareance
# name
# Hank Pym         male               1962
# Scarlet Witch  female               1964
# Wasp           female               1963
# Black Widow    female               1964
# Vision           male               1968

# %%
marvel_df.loc[:"Thor", ["gender"]]
# Out:
#                 gender
# name
# Spider-Man        male
# Captain America   male
# Wolverine         male
# Iron Man          male
# Thor              male

# %%
marvel_df.iloc[1:-1].first_appeareance
# Out:
# name
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Namor               1939
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Hank Pym            1962
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Name: first_appeareance, dtype: int64

# %%
marvel_df.iloc[[1,-1]]
# Out:
#                 gender  first_appeareance
# name
# Captain America   male               1941
# Vision            male               1968

# %%
marvel_df
# Out:
#                   gender  first_appeareance
# name
# Spider-Man          male               1962
# Captain America     male               1941
# Wolverine           male               1974
# Iron Man            male               1963
# Thor                male               1963
# Thing               male               1961
# Mister Fantastic    male               1961
# Hulk                male               1962
# Beast               male               1963
# Invisible Woman   female               1961
# Storm             female               1975
# Namor               male               1939
# Hawkeye             male               1964
# Daredevil           male               1964
# Doctor Strange      male               1963
# Hank Pym            male               1962
# Scarlet Witch     female               1964
# Wasp              female               1963
# Black Widow       female               1964
# Vision              male               1968

# %%
marvel_df.loc["Vision","first_appeareance"] = 1964
marvel_df
# Out:
#                   gender  first_appeareance
# name
# Spider-Man          male               1962
# Captain America     male               1941
# Wolverine           male               1974
# Iron Man            male               1963
# Thor                male               1963
# Thing               male               1961
# Mister Fantastic    male               1961
# Hulk                male               1962
# Beast               male               1963
# Invisible Woman   female               1961
# Storm             female               1975
# Namor               male               1939
# Hawkeye             male               1964
# Daredevil           male               1964
# Doctor Strange      male               1963
# Hank Pym            male               1962
# Scarlet Witch     female               1964
# Wasp              female               1963
# Black Widow       female               1964
# Vision              male               1964

# %%
marvel_df["years_since"] = 2023 - marvel_df["first_appeareance"]
marvel_df
# Out:
#                   gender  first_appeareance  years_since
# name
# Spider-Man          male               1962           61
# Captain America     male               1941           82
# Wolverine           male               1974           49
# Iron Man            male               1963           60
# Thor                male               1963           60
# Thing               male               1961           62
# Mister Fantastic    male               1961           62
# Hulk                male               1962           61
# Beast               male               1963           60
# Invisible Woman   female               1961           62
# Storm             female               1975           48
# Namor               male               1939           84
# Hawkeye             male               1964           59
# Daredevil           male               1964           59
# Doctor Strange      male               1963           60
# ...

# %%
marvel_df[marvel_df["gender"] == "female"]
# Out:
#                  gender  first_appeareance  years_since
# name
# Invisible Woman  female               1961           62
# Storm            female               1975           48
# Scarlet Witch    female               1964           59
# Wasp             female               1963           60
# Black Widow      female               1964           59

# %%
marvel_df[marvel_df["gender"] == "male"]
# Out:
#                  gender  first_appeareance  years_since
# name
# Spider-Man         male               1962           61
# Captain America    male               1941           82
# Wolverine          male               1974           49
# Iron Man           male               1963           60
# Thor               male               1963           60
# Thing              male               1961           62
# Mister Fantastic   male               1961           62
# Hulk               male               1962           61
# Beast              male               1963           60
# Namor              male               1939           84
# Hawkeye            male               1964           59
# Daredevil          male               1964           59
# Doctor Strange     male               1963           60
# Hank Pym           male               1962           61
# Vision             male               1964           59

# %%
marvel_df[marvel_df["first_appeareance"] > 1970]
# Out:
#            gender  first_appeareance  years_since
# name
# Wolverine    male               1974           49
# Storm      female               1975           48

# %%
marvel_df[(marvel_df["gender"] == "female") & (marvel_df["first_appeareance"] > 1970)]
# Out:
#        gender  first_appeareance  years_since
# name
# Storm  female               1975           48

# %%
marvel_df.describe()
# Out:
#        first_appeareance  years_since
# count          20.000000    20.000000
# mean         1961.650000    61.350000
# std             8.298859     8.298859
# min          1939.000000    48.000000
# 25%          1961.750000    59.000000
# 50%          1963.000000    60.000000
# 75%          1964.000000    61.250000
# max          1975.000000    84.000000

# %%
marvel_df["first_appeareance"].mean()
# Out:
# 1961.65

# %%
marvel_df.first_appeareance.min()
# Out:
# 1939

# %%
marvel_df[marvel_df.first_appeareance == marvel_df.first_appeareance.min()]
# Out:
#       gender  first_appeareance  years_since
# name
# Namor   male               1939           84

# %%
marvel_df = marvel_df.reset_index()

marvel_df
# Out:
#                 name  gender  first_appeareance  years_since
# 0         Spider-Man    male               1962           61
# 1    Captain America    male               1941           82
# 2          Wolverine    male               1974           49
# 3           Iron Man    male               1963           60
# 4               Thor    male               1963           60
# 5              Thing    male               1961           62
# 6   Mister Fantastic    male               1961           62
# 7               Hulk    male               1962           61
# 8              Beast    male               1963           60
# 9    Invisible Woman  female               1961           62
# 10             Storm  female               1975           48
# 11             Namor    male               1939           84
# 12           Hawkeye    male               1964           59
# 13         Daredevil    male               1964           59
# ...

# %%
marvel_df["first_appeareance"].plot()
# Out:
# <AxesSubplot: >

# %%
marvel_df.first_appeareance.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>
